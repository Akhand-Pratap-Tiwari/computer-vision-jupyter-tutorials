# %% [markdown]
# # Hough Transform

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
img = cv2.imread('cube.jpg')
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img)

# %% [markdown]
# Try to use good quality images with appropriate resolution otherwise the program may not work

# %%
edges = cv2.Canny(img_gray, 50, 150, apertureSize=3)
lines = cv2.HoughLines(edges, 1, np.pi/180, 200)
display(lines)
for line in lines:
    rho, t = line[0]
    a = np.cos(t)
    b = np.sin(t)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))
    cv2.line(img, (x1, y1), (x2, y2), (0, 0, 255), 5)
plt.imshow(edges)
plt.imshow(img)
# Out:
# array([[[8.0800000e+02, 3.4906585e-02]],
#
#        [[6.9000000e+01, 1.7278759e+00]],
#
#        [[6.4200000e+02, 1.2915436e+00]],
#
#        [[1.0610000e+03, 1.1868238e+00]],
#
#        [[3.8400000e+02, 1.7976891e+00]],
#
#        [[5.2300000e+02, 0.0000000e+00]],
#
#        [[3.7700000e+02, 1.7453292e-02]]], dtype=float32)
